# %%
import pandas as pd

# Data output of 35 runs WITHOUT changing output
data = [
    [3, 25, 25.56, 10.692352407211427],
    [4, 23, 22.82608695652174, 9.671347974538632],
    [5, 23, 26.043478260869566, 10.674953460318326],
    [6, 22, 26.045454545454547, 9.749019870210137],
    [7, 25, 26.0, 10.721940122944167],
    [8, 23, 26.956521739130434, 9.072070186397298],
    [9, 21, 25.714285714285715, 10.624064584673784],
    [10, 24, 28.625, 8.572302782799964],
    [11, 22, 27.863636363636363, 10.402340010110725],
    [12, 23, 27.608695652173914, 10.618847601582447],
    [13, 23, 24.652173913043477, 9.029462383014616],
    [14, 24, 27.166666666666668, 8.463975950396414],
    [15, 23, 27.17391304347826, 11.012452137439467],
    [16, 23, 27.434782608695652, 9.417033996995396],
    [17, 25, 25.04, 8.774873218457348],
    [18, 23, 28.652173913043477, 11.153508692051453],
    [19, 25, 27.24, 10.397230400447997],
    [20, 24, 26.375, 9.547305466290824],
    [21, 24, 28.916666666666668, 9.586955837085213],
    [22, 23, 25.782608695652176, 11.092326065462244],
    [23, 23, 26.782608695652176, 9.495795507757197],
    [24, 25, 27.64, 9.225529795084942],
    [25, 22, 24.818181818181817, 7.929440904493282],
    [26, 25, 25.2, 9.695359714832659],
    [27, 25, 26.8, 10.650821564555478],
    [28, 21, 26.095238095238095, 9.033824069809144],
    [29, 27, 26.925925925925927, 10.65251118342673],
    [30, 26, 24.96153846153846, 10.04788829414408],
    [31, 24, 28.666666666666668, 10.438976109859732],
    [32, 23, 26.347826086956523, 9.029462383014616],
    [33, 25, 28.08, 10.665533273118601],
    [34, 25, 26.68, 8.210822126924928],
    [35, 21, 26.285714285714285, 10.383791660645965],
    [36, 23, 26.26086956521739, 11.105100243481342],
    [37, 24, 27.5, 12.027745701779143]
]

# Create DataFrame
df = pd.DataFrame(data, columns=["Run", "Quantity", "AvgPrice", "SD"])

# Display DataFrame
#print(df)
print("Min and Max Average Price")
print(df["AvgPrice"].min())
print(df["AvgPrice"].max())

print("Min and Max Quantity")
print(df["Quantity"].min())
print(df["Quantity"].max())

# Print variance
print("Variance in Quantity (run to run):", df["Quantity"].var())

# Print variance of Average Price
print("Variance in Average Price (run to run):", df["AvgPrice"].var())

# Print variance of Standard Deviation
print("Variance in Standard Deviation:", df['SD'].var() )
# Out:
# Min and Max Average Price
# 22.82608695652174
# 28.916666666666668
# Min and Max Quantity
# 21
# 27
# Variance in Quantity (run to run): 2.0050420168067227
# Variance in Average Price (run to run): 1.738172946581334
# Variance in Standard Deviation: 0.9362720886617417

# %%
# Data from output of 35 runs with changing of agents
data1 = [
    [1, 28, 23.964285714285715, 11.459500558978323],
    [2, 28, 24.964285714285715, 9.788776893015005],
    [3, 24, 27.375, 10.331232985466933],
    [4, 24, 21.625, 11.58235907173779],
    [5, 23, 25.26086956521739, 11.452045161205536],
    [6, 26, 27.576923076923077, 10.081106002064063],
    [7, 24, 26.625, 9.187003954862906],
    [8, 22, 23.90909090909091, 10.548197135525927],
    [9, 28, 27.214285714285715, 11.238826650936295],
    [10, 29, 24.689655172413794, 10.362743107337948],
    [11, 29, 24.344827586206897, 9.827041727203794],
    [12, 28, 26.285714285714285, 11.112596272625373],
    [13, 24, 28.291666666666668, 7.9082191772582755],
    [14, 22, 24.40909090909091, 9.068722927578618],
    [15, 28, 24.392857142857142, 8.97750874493064],
    [16, 21, 24.571428571428573, 11.004637241469004],
    [17, 27, 26.925925925925927, 10.800980497076027],
    [18, 18, 26.61111111111111, 7.0169547754697446],
    [19, 22, 26.454545454545453, 11.691983550229747],
    [20, 26, 23.653846153846153, 8.548244568746298],
    [21, 26, 27.576923076923077, 11.446104735213087],
    [22, 24, 20.125, 8.978272383927768],
    [23, 28, 27.607142857142858, 9.748037479096885],
    [24, 29, 26.20689655172414, 10.567938859963146],
    [25, 23, 23.869565217391305, 10.975483936348823],
    [26, 23, 25.91304347826087, 9.050164752179262],
    [27, 22, 24.59090909090909, 9.388867154576264],
    [28, 27, 22.666666666666668, 8.781293248212995],
    [29, 25, 25.68, 10.769289670168595],
    [30, 28, 26.142857142857142, 9.963197585235825],
    [31, 18, 26.5, 9.668103341515451],
    [32, 27, 25.074074074074073, 8.927385772736258],
    [33, 22, 27.136363636363637, 9.016628348604566],
    [34, 22, 27.545454545454547, 9.907422711956345],
    [35, 27, 28.25925925925926, 11.097522554998957]
]

# Create DataFrame
df1 = pd.DataFrame(data1, columns=["Run", "Quantity", "AvgPrice", "SD"])

# Display DataFrame
#print(df)
print("Min and Max Average Price")
print(df1["AvgPrice"].min())
print(df1["AvgPrice"].max())

print("Min and Max Quantity")
print(df1["Quantity"].min())
print(df1["Quantity"].max())


# Print variance
print("Variance in Quantity (run to run):", df1["Quantity"].var())

# Print variance of Average Price
print("Variance in Average Price:", df1["AvgPrice"].var())

# Print variance of Standard Deviation
print("Variance in Standard Deviation:", df1['SD'].var() )
# Out:
# Min and Max Average Price
# 20.125
# 28.291666666666668
# Min and Max Quantity
# 18
# 29
# Variance in Quantity (run to run): 9.257142857142854
# Variance in Average Price: 3.5121063142182156
# Variance in Standard Deviation: 1.2903679606430065

# %%
# Compare the two DataFrames
comparison = df.compare(df1)

# Display the comparison
print(comparison)
# Out:
#     Run       Quantity         AvgPrice                    SD
#    self other     self other       self      other       self      other
# 0     3     1       25    28  25.560000  23.964286  10.692352  11.459501
# 1     4     2       23    28  22.826087  24.964286   9.671348   9.788777
# 2     5     3       23    24  26.043478  27.375000  10.674953  10.331233
# 3     6     4       22    24  26.045455  21.625000   9.749020  11.582359
# 4     7     5       25    23  26.000000  25.260870  10.721940  11.452045
# 5     8     6       23    26  26.956522  27.576923   9.072070  10.081106
# 6     9     7       21    24  25.714286  26.625000  10.624065   9.187004
# 7    10     8       24    22  28.625000  23.909091   8.572303  10.548197
# 8    11     9       22    28  27.863636  27.214286  10.402340  11.238827
# 9    12    10       23    29  27.608696  24.689655  10.618848  10.362743
# 10   13    11       23    29  24.652174  24.344828   9.029462   9.827042
# ...

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Data for the first DataFrame
data1 = [
    [3, 25, 25.56, 10.692352407211427],
    [4, 23, 22.82608695652174, 9.671347974538632],
    [5, 23, 26.043478260869566, 10.674953460318326],
    [6, 22, 26.045454545454547, 9.749019870210137],
    [7, 25, 26.0, 10.721940122944167],
    [8, 23, 26.956521739130434, 9.072070186397298],
    [9, 21, 25.714285714285715, 10.624064584673784],
    [10, 24, 28.625, 8.572302782799964],
    [11, 22, 27.863636363636363, 10.402340010110725],
    [12, 23, 27.608695652173914, 10.618847601582447],
    [13, 23, 24.652173913043477, 9.029462383014616],
    [14, 24, 27.166666666666668, 8.463975950396414],
    [15, 23, 27.17391304347826, 11.012452137439467],
    [16, 23, 27.434782608695652, 9.417033996995396],
    [17, 25, 25.04, 8.774873218457348],
    [18, 23, 28.652173913043477, 11.153508692051453],
    [19, 25, 27.24, 10.397230400447997],
    [20, 24, 26.375, 9.547305466290824],
    [21, 24, 28.916666666666668, 9.586955837085213],
    [22, 23, 25.782608695652176, 11.092326065462244],
    [23, 23, 26.782608695652176, 9.495795507757197],
    [24, 25, 27.64, 9.225529795084942],
    [25, 22, 24.818181818181817, 7.929440904493282],
    [26, 25, 25.2, 9.695359714832659],
    [27, 25, 26.8, 10.650821564555478],
    [28, 21, 26.095238095238095, 9.033824069809144],
    [29, 27, 26.925925925925927, 10.65251118342673],
    [30, 26, 24.96153846153846, 10.04788829414408],
    [31, 24, 28.666666666666668, 10.438976109859732],
    [32, 23, 26.347826086956523, 9.029462383014616],
    [33, 25, 28.08, 10.665533273118601],
    [34, 25, 26.68, 8.210822126924928],
    [35, 21, 26.285714285714285, 10.383791660645965],
    [36, 23, 26.26086956521739, 11.105100243481342],
    [37, 24, 27.5, 12.027745701779143]
]

df1 = pd.DataFrame(data1, columns=["Index", "Value1", "Value2", "Value3"])

# Data for the second DataFrame
data2 = [
    [1, 28, 23.964285714285715, 11.459500558978323],
    [2, 28, 24.964285714285715, 9.788776893015005],
    [3, 24, 27.375, 10.331232985466933],
    [4, 24, 21.625, 11.58235907173779],
    [5, 23, 25.26086956521739, 11.452045161205536],
    [6, 26, 27.576923076923077, 10.081106002064063],
    [7, 24, 26.625, 9.187003954862906],
    [8, 22, 23.90909090909091, 10.548197135525927],
    [9, 28, 27.214285714285715, 11.238826650936295],
    [10, 29, 24.689655172413794, 10.362743107337948],
    [11, 29, 24.344827586206897, 9.827041727203794],
    [12, 28, 26.285714285714285, 11.112596272625373],
    [13, 24, 28.291666666666668, 7.9082191772582755],
    [14, 22, 24.40909090909091, 9.068722927578618],
    [15, 28, 24.392857142857142, 8.97750874493064],
    [16, 21, 24.571428571428573, 11.004637241469004],
    [17, 27, 26.925925925925927, 10.800980497076027],
    [18, 18, 26.61111111111111, 7.0169547754697446],
    [19, 22, 26.454545454545453, 11.691983550229747],
    [20, 26, 23.653846153846153, 8.548244568746298],
    [21, 26, 27.576923076923077, 11.446104735213087],
    [22, 24, 20.125, 8.978272383927768],
    [23, 28, 27.607142857142858, 9.748037479096885],
    [24, 29, 26.20689655172414, 10.567938859963146],
    [25, 23, 23.869565217391305, 10.975483936348823],
    [26, 23, 25.91304347826087, 9.050164752179262],
    [27, 22, 24.59090909090909, 9.388867154576264],
    [28, 27, 22.666666666666668, 8.781293248212995],
    [29, 25, 25.68, 10.769289670168595],
    [30, 28, 26.142857142857142, 9.963197585235825],
    [31, 18, 26.5, 9.668103341515451],
    [32, 27, 25.074074074074073, 8.927385772736258],
    [33, 22, 27.136363636363637, 9.016628348604566],
    [34, 22, 27.545454545454547, 9.907422711956345],
    [35, 27, 28.25925925925926, 11.097522554998957]
]

df2 = pd.DataFrame(data2, columns=["Index", "Value1", "Value2", "Value3"])

# Add a column to indicate the source dataframe
df1['Source'] = 'DF1'
df2['Source'] = 'DF2'

# Combine the dataframes
combined_df = pd.concat([df1, df2])

# Fit the model
model = ols('Value3 ~ C(Source)', data=combined_df).fit()

# Perform ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)

# Display ANOVA table
print(anova_table)
# Out:
#               sum_sq    df         F    PR(>F)
# C(Source)   0.082796   1.0  0.074368  0.785906
# Residual   75.705762  68.0       NaN       NaN
